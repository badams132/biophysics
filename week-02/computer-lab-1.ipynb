# %% [markdown]
# # Computer Lab 1
#
# Work through the first half of "First Computer Lab" (Section 5.1) in _A Student's Guide to Python._  This exercise ties together everything we did in Week 1.
#
# You can use this notebook to store your code, plots, and notes, or you can write a ___script___ (see Section 3.3) that will carry out the analysis and produce the plots, and simply write your comments in this notebook.  If you write a script, it should save your plot with the data and your best fit to a PDF in this folder when it runs.

# %%
# %run lab5_script.py

# %% [markdown]
# ## B) I was just left with beta as my lone variable to adjust, and this is the best representaion that has a clear starting and ending trend that is similar to the data. It seems very difficult to fit this model to the data, and we may need a different equation to create something that can explain the sharp increase at the begining.

# %% [markdown]
# ## C) The data goes up to 7 years so and with exponential decay, so I would say it trends the same way. I am not sure I am understanding fully tho, they might trend opposite but either way is expected.
