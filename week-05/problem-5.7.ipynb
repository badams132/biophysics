# %% [markdown]
# # Problem 5.7
#
# Use this notebook to present your work on the problem.  If you write scripts, store them in this folder and run them within this notebook to produce the requested histograms.

# %% [markdown]
# ## (a) __Histogram of $1/x$__

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

x = np.linspace(0.1,1,10000)


y = 1 / x

# %%
plt.hist(y,40);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## (b) Log-log plot of frequencies

# %%
plt.loglog(x,y,'r')

# %% [markdown]
# ## (c) Analysis and Conclusions

# %% [markdown]
# ### The Log plot of both x and y is decreasing and shows that there is a linear relationship between both variables.

# %% [markdown]
# ## (d) Numerical experiments with more samples

# %% [markdown]
# ### The high-x region of my plot is uniform for the most part. It has a non zero slope that is negative. When I increase to 50,000 samples the plot becomes even more uniform.
