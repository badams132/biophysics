# %% [markdown]
# # 11.2 COOPERATIVE BINDING DATA
#
# Use this notebook to store your work for this problem.

# %% [markdown]
# ## (a) Fit by eye

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = np.loadtxt('hemoglobin.csv' , delimiter=',')

data_conc = data [0:45:1,0]
data_p = data [0:45:1,1]

plt.plot(data_conc,data_p)

x = np.linspace(0,3,1000)

y = 1/(1+(x**2))

plt.plot(x*.00001,y,'k')

# %% [markdown]
# ## (b) Least-squares fit

# %% [markdown]
# ## I feel like i have answered this in ther previous code segment. It was hard to fit the data, and am not sure if you wanted loglog plots or vice versa. But the line seems to trend in the same way.
