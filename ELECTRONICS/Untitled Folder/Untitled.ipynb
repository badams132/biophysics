# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

vsg=np.loadtxt('VSG=-2,5.py.csv' , delimiter=',')
print(vsg)

ID=vsg[0:11:1,1]  # slice
#print(ID)

VSD=vsg[0:11:1,0]
#print(VSD);

plt.plot(VSD,ID,'ro-')


#help(plt.xlim)
plt.xlim(.5,-10.5)
plt.ylim(0,-0.5)
plt.title("VSG = -2.5V", size='24',weight='bold')
plt.xlabel("VDS (V)",weight='bold')
plt.ylabel("ID (mA)", weight='bold')
# Out:
# [[ -0.05    -0.0153]
#  [ -0.1     -0.0303]
#  [ -0.25    -0.0742]
#  [ -0.5     -0.1425]
#  [ -1.      -0.307 ]
#  [ -1.79    -0.386 ]
#  [ -2.5     -0.406 ]
#  [ -5.      -0.44  ]
#  [ -7.5     -0.464 ]
#  [-10.      -0.482 ]]
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'ID (mA)')

# %%
vsg=np.loadtxt('VSG= -5.csv' , delimiter=',')
print(vsg)

ID=vsg[0:11:1,1]  # slice
#print(ID)

VSD=vsg[0:11:1,0]
#print(VSD);

plt.plot(VSD,ID,'ro-')


#help(plt.xlim)
plt.xlim(.5,-10.5)
plt.ylim(0,-0.5)
plt.title("VSG = -2.5V", size='24',weight='bold')
plt.xlabel("VDS (V)",weight='bold')
plt.ylabel("ID (mA)", weight='bold')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19912/4189437449.py in <module>
# ----> 1 vsg=np.loadtxt('VSG= -5.csv' , delimiter=',')
#       2 print(vsg)
#       3
#       4 ID=vsg[0:11:1,1]  # slice
#       5 #print(ID)
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ~\anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     192
#     193     ds = DataSource(destpath)
# ...
