# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import beta

# %%
mu = np.linspace(-1.5,1.5,101)
x = .1
S = .1
sigma = .1
sigma1 = .6
sigma2 = .070711
sigma3 = .2798
A = 1 / (sigma * np.sqrt(2*np.pi)) * np.exp(-(mu)**2 / (2*S**2))
B1 = 1 / (sigma * np.sqrt(2*np.pi)) * np.exp(-(x - mu)**2 / (2*sigma**2))
B2 = 1 / (sigma3 * np.sqrt(2*np.pi)) *np.exp(-(x - mu)**2 / (2*sigma1**2))
C1 = 1 / (sigma2 * np.sqrt(2*np.pi)) * np.exp(-(mu-x/2)**2/ (2 * sigma2**2))
C2 = 1 / (sigma3 * np.sqrt(2*np.pi)) * np.exp(-(mu-x*.435)**2/ (2 * sigma3**2))

# %%
plt.plot(mu, A,'k')
plt.plot(mu, B1, 'r')
plt.plot(mu, B2, 'g')
plt.plot(mu, C1, 'm')
plt.plot(mu , C2, 'b')

# %%
delta = 0.063
dxi = xi[1]-xi[0]
p[(xi>0.17-delta) * (xi<0.17+delta) ].sum() *dxi
# Out:
# 0.9024641415779011
